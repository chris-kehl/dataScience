# %%
# import the data 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Using pandas to look at the data
data = pd.read_csv('data/Crime_Data_2019.csv')

data.head(5)
# Out:
# /Users/chriskehl/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   INCIDENT_NUMBER  DATE_REPORTED   DATE_OCCURED  \
# 0    80-19-011839   2/16/19 7:44   2/16/19 3:52
# 1    80-19-011841   2/16/19 8:00   2/16/19 4:00
# 2    80-19-011851  2/15/19 16:21  2/13/19 16:15
# 3    80-19-011881  2/16/19 12:38  2/10/19 11:30
# 4    80-19-011884  2/16/19 13:00   2/10/19 0:00
#
#                                             UOR_DESC     CRIME_TYPE  \
# 0  TBUT OR DISP SHOPLIFTING $500 OR >  BUT < $10,000  THEFT/LARCENY
# 1            PROPERTY LOST OR ABANDONED NON CRIMINAL          OTHER
# 2                              BURGLARY - 3RD DEGREE       BURGLARY
# 3       TBUT OR DISP ALL OTHERS > $500 BUT < $10,000  THEFT/LARCENY
# 4       TBUT OR DISP ALL OTHERS > $500 BUT < $10,000  THEFT/LARCENY
#
#   NIBRS_CODE UCR_HIERARCHY   ATT_COMP LMPD_DIVISION LMPD_BEAT  \
# 0        23C        PART I  COMPLETED  3RD DIVISION       315
# 1        90Z       PART II  COMPLETED  3RD DIVISION       322
# 2        220        PART I  COMPLETED  3RD DIVISION       331
# 3        23H        PART I  COMPLETED  2ND DIVISION       236
# 4        23H        PART I  COMPLETED  4TH DIVISION       424
#
#                       PREMISE_TYPE  \
# 0  DRUG STORE/DR`S OFFICE/HOSPITAL
# 1                 RESIDENCE / HOME
# 2        RENTAL / STORAGE FACILITY
# 3                 RESIDENCE / HOME
# 4                 RESIDENCE / HOME
#
#                                        BLOCK_ADDRESS        CITY ZIP_CODE  \
# 0  7500 BLOCK TERRY RD                           ...  LOUISVILLE    40258
# 1  3000 BLOCK SPRINGFIELD DR                     ...  LOUISVILLE    40214
# 2  5500 BLOCK GREENBELT HWY                      ...  LOUISVILLE    40216
# 3  4000 BLOCK WILMOTH AVE                        ...  LOUISVILLE    40216
# 4  3900 BLOCK S 2ND ST                           ...  LOUISVILLE    40214
#
#         ID
# 0  1224259
# 1  1224260
# 2  1224261
# 3  1224262
# 4  1224263

# %%
# look at the data type and summary of statistics
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146253 entries, 0 to 146252
# Data columns (total 15 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   INCIDENT_NUMBER  146253 non-null  object
#  1   DATE_REPORTED    146253 non-null  object
#  2   DATE_OCCURED     146252 non-null  object
#  3   UOR_DESC         146253 non-null  object
#  4   CRIME_TYPE       146253 non-null  object
#  5   NIBRS_CODE       146253 non-null  object
#  6   UCR_HIERARCHY    143159 non-null  object
#  7   ATT_COMP         146110 non-null  object
#  8   LMPD_DIVISION    146253 non-null  object
#  9   LMPD_BEAT        146195 non-null  object
#  10  PREMISE_TYPE     146223 non-null  object
#  11  BLOCK_ADDRESS    146253 non-null  object
#  12  CITY             146230 non-null  object
#  13  ZIP_CODE         145800 non-null  object
#  14  ID               146253 non-null  int64
# dtypes: int64(1), object(14)
# memory usage: 16.7+ MB

# %%
# find out if there are any null values
data.isnull().values.any()
# Out:
# True

# %%
# check and see where the null values are at
null_counts = data.isnull().sum()
null_counts[null_counts > 0].sort_values(ascending=False)
# Out:
# UCR_HIERARCHY    3094
# ZIP_CODE          453
# ATT_COMP          143
# LMPD_BEAT          58
# PREMISE_TYPE       30
# CITY               23
# DATE_OCCURED        1
# dtype: int64

# %%
# Look up crime where PREMISE_TYPE = SERVICE / GAS STATION and ZIP Code is 40272

# look at the premise type and crime type
by_Premise = pd.crosstab(data['CRIME_TYPE'], data['PREMISE_TYPE'])
by_Premise
# Out:
# PREMISE_TYPE              ABANDONED/CONDEMNED STRUCTURE  \
# CRIME_TYPE
# ARSON                                                 1
# ASSAULT                                               6
# BURGLARY                                             18
# DISTURBING THE PEACE                                  2
# DRUGS/ALCOHOL VIOLATIONS                             24
# DUI                                                   0
# FRAUD                                                 1
# HOMICIDE                                              0
# MOTOR VEHICLE THEFT                                   0
# OTHER                                                 3
# ROBBERY                                               1
# SEX CRIMES                                            9
# THEFT/LARCENY                                         2
# VANDALISM                                             7
# VEHICLE BREAK-IN/THEFT                                0
# WEAPONS                                               3
#
# PREMISE_TYPE              AIR / BUS / TRAIN TERMINAL  AMUSEMENT PARK  \
# CRIME_TYPE
# ARSON                                              0               0
# ASSAULT                                           28              13
# BURGLARY                                           1               1
# DISTURBING THE PEACE                               0               1
# DRUGS/ALCOHOL VIOLATIONS                           8               2
# DUI                                                0               0
# FRAUD                                              5               2
# HOMICIDE                                           0               0
# MOTOR VEHICLE THEFT                                6               1
# OTHER                                             41               6
# ROBBERY                                            5               2
# SEX CRIMES                                         1               0
# THEFT/LARCENY                                     49              25
# VANDALISM                                         10               1
# VEHICLE BREAK-IN/THEFT                             2               2
# WEAPONS                                            1               0
#
# PREMISE_TYPE              ATM SEPARATE FROM BANK  ATTACHED RESIDENTIAL GARAGE  \
# CRIME_TYPE
# ARSON                                          0                            1
# ASSAULT                                        5                            1
# BURGLARY                                       0                          115
# DISTURBING THE PEACE                           0                            1
# DRUGS/ALCOHOL VIOLATIONS                       0                            0
# DUI                                            0                            0
# FRAUD                                         69                            0
# HOMICIDE                                       0                            0
# MOTOR VEHICLE THEFT                            0                            3
# OTHER                                          3                            4
# ROBBERY                                        1                            1
# SEX CRIMES                                     0                            0
# THEFT/LARCENY                                  6                            4
# VANDALISM                                      1                            6
# VEHICLE BREAK-IN/THEFT                         1                            6
# WEAPONS                                        0                            0
#
# PREMISE_TYPE              AUTO DEALERSHIP (NEW OR USED)  \
# CRIME_TYPE
# ARSON                                                 1
# ASSAULT                                              16
# BURGLARY                                             64
# DISTURBING THE PEACE                                  2
# DRUGS/ALCOHOL VIOLATIONS                             10
# DUI                                                   0
# FRAUD                                                96
# HOMICIDE                                              0
# MOTOR VEHICLE THEFT                                 163
# OTHER                                                40
# ROBBERY                                               2
# SEX CRIMES                                            0
# THEFT/LARCENY                                        67
# VANDALISM                                            54
# VEHICLE BREAK-IN/THEFT                              152
# WEAPONS                                               0
#
# PREMISE_TYPE              BANK / SAVINGS & LOAN  BAR / NIGHT CLUB  \
# CRIME_TYPE
# ARSON                                         0                 1
# ASSAULT                                      22               234
# BURGLARY                                      3                25
# DISTURBING THE PEACE                          1                 7
# DRUGS/ALCOHOL VIOLATIONS                      5                39
# DUI                                           0                 0
# FRAUD                                       382                21
# HOMICIDE                                      0                 3
# MOTOR VEHICLE THEFT                           4                34
# OTHER                                        33                52
# ROBBERY                                      33                15
# SEX CRIMES                                    0                 6
# THEFT/LARCENY                               192               197
# VANDALISM                                    43                43
# VEHICLE BREAK-IN/THEFT                        7                26
# WEAPONS                                       2                 4
#
# PREMISE_TYPE              CAMP / CAMPGROUND  CEMETERY / GRAVEYARD  ...  \
# CRIME_TYPE                                                         ...
# ARSON                                     0                     0  ...
# ASSAULT                                   3                     2  ...
# BURGLARY                                  1                     3  ...
# DISTURBING THE PEACE                      0                     0  ...
# DRUGS/ALCOHOL VIOLATIONS                  0                    11  ...
# DUI                                       0                     0  ...
# FRAUD                                     0                     0  ...
# HOMICIDE                                  0                     0  ...
# MOTOR VEHICLE THEFT                       1                     1  ...
# OTHER                                    31                     4  ...
# ROBBERY                                   1                     1  ...
# SEX CRIMES                                0                     0  ...
# THEFT/LARCENY                             1                     3  ...
# VANDALISM                                 0                    11  ...
# VEHICLE BREAK-IN/THEFT                    2                     8  ...
# WEAPONS                                   0                     0  ...
#
# PREMISE_TYPE              PARK / PLAYGROUND  PARKING LOT / GARAGE  \
# CRIME_TYPE
# ARSON                                     1                     4
# ASSAULT                                 153                   849
# BURGLARY                                 10                    76
# DISTURBING THE PEACE                      4                    31
# DRUGS/ALCOHOL VIOLATIONS                131                   752
# DUI                                       0                     0
# FRAUD                                     7                   144
# HOMICIDE                                  7                    28
# MOTOR VEHICLE THEFT                      17                  2146
# OTHER                                    80                   571
# ROBBERY                                  50                   273
# SEX CRIMES                               17                    20
# THEFT/LARCENY                           116                  1629
# VANDALISM                                90                  1577
# VEHICLE BREAK-IN/THEFT                  238                  5207
# WEAPONS                                  28                    71
#
# PREMISE_TYPE              RACE TRACK/GAMBLING FACILITY  \
# CRIME_TYPE
# ARSON                                                1
# ASSAULT                                             11
# BURGLARY                                             1
# DISTURBING THE PEACE                                 0
# DRUGS/ALCOHOL VIOLATIONS                             7
# DUI                                                  0
# FRAUD                                                4
# HOMICIDE                                             0
# MOTOR VEHICLE THEFT                                  1
# OTHER                                               14
# ROBBERY                                              0
# SEX CRIMES                                           1
# THEFT/LARCENY                                       55
# VANDALISM                                            2
# VEHICLE BREAK-IN/THEFT                               4
# WEAPONS                                              1
#
# PREMISE_TYPE              RENTAL / STORAGE FACILITY  RESIDENCE / HOME  \
# CRIME_TYPE
# ARSON                                             2                81
# ASSAULT                                          19             18055
# BURGLARY                                        695              4770
# DISTURBING THE PEACE                             10               445
# DRUGS/ALCOHOL VIOLATIONS                         19              2573
# DUI                                               0                 1
# FRAUD                                            92              1445
# HOMICIDE                                          0                96
# MOTOR VEHICLE THEFT                              41              3886
# OTHER                                            37             10142
# ROBBERY                                           3               505
# SEX CRIMES                                        0               686
# THEFT/LARCENY                                   141              8167
# VANDALISM                                        91              5314
# VEHICLE BREAK-IN/THEFT                           41              4738
# WEAPONS                                           0               501
#
# PREMISE_TYPE              RESTAURANT  SCHOOL - COLLEGE / UNIVERSITY  \
# CRIME_TYPE
# ARSON                              0                              1
# ASSAULT                          400                             18
# BURGLARY                         168                              4
# DISTURBING THE PEACE              10                              1
# DRUGS/ALCOHOL VIOLATIONS          64                              3
# DUI                                0                              0
# FRAUD                            279                              1
# HOMICIDE                           2                              0
# MOTOR VEHICLE THEFT               49                              3
# OTHER                            172                              8
# ROBBERY                           53                              1
# SEX CRIMES                         9                              2
# THEFT/LARCENY                    637                             33
# VANDALISM                        207                             35
# VEHICLE BREAK-IN/THEFT            54                              7
# WEAPONS                           10                              2
#
# PREMISE_TYPE              SCHOOL - ELEMENTARY / SECONDARY  \
# CRIME_TYPE
# ARSON                                                   2
# ASSAULT                                               189
# BURGLARY                                               18
# DISTURBING THE PEACE                                    4
# DRUGS/ALCOHOL VIOLATIONS                               37
# DUI                                                     0
# FRAUD                                                   6
# HOMICIDE                                                0
# MOTOR VEHICLE THEFT                                     5
# OTHER                                                 126
# ROBBERY                                                 5
# SEX CRIMES                                             18
# THEFT/LARCENY                                          71
# VANDALISM                                              41
# VEHICLE BREAK-IN/THEFT                                 25
# WEAPONS                                                17
#
# PREMISE_TYPE              SERVICE / GAS STATION  \
# CRIME_TYPE
# ARSON                                         3
# ASSAULT                                     303
# BURGLARY                                     78
# DISTURBING THE PEACE                         17
# DRUGS/ALCOHOL VIOLATIONS                    190
# DUI                                           0
# FRAUD                                       437
# HOMICIDE                                      3
# MOTOR VEHICLE THEFT                         240
# OTHER                                       134
# ROBBERY                                     134
# SEX CRIMES                                    3
# THEFT/LARCENY                               898
# VANDALISM                                   142
# VEHICLE BREAK-IN/THEFT                      106
# WEAPONS                                      21
#
# PREMISE_TYPE              SPECIALTY STORE (TV, FUR, ETC)
# CRIME_TYPE
# ARSON                                                  0
# ASSAULT                                              107
# BURGLARY                                             276
# DISTURBING THE PEACE                                   7
# DRUGS/ALCOHOL VIOLATIONS                              13
# DUI                                                    0
# FRAUD                                                244
# HOMICIDE                                               0
# MOTOR VEHICLE THEFT                                   37
# OTHER                                                 58
# ROBBERY                                               45
# SEX CRIMES                                             7
# THEFT/LARCENY                                       1120
# VANDALISM                                            164
# VEHICLE BREAK-IN/THEFT                                60
# WEAPONS                                                3
#
# [16 rows x 47 columns]

# %%
d = data.groupby(['PREMISE_TYPE']).size().sort_values(ascending=False)
top10_premiseType=d.head(10)
top10_premiseType
# Out:
# PREMISE_TYPE
# RESIDENCE / HOME                     61405
# HIGHWAY / ROAD / ALLEY               24104
# PARKING LOT / GARAGE                 13378
# OTHER RESIDENCE (APARTMENT/CONDO)     8310
# OTHER / UNKNOWN                       5803
# DEPARTMENT / DISCOUNT STORE           5361
# SERVICE / GAS STATION                 2709
# CONVENIENCE STORE                     2266
# SPECIALTY STORE (TV, FUR, ETC)        2141
# RESTAURANT                            2114
# dtype: int64

# %%
sns.set_context('paper')

f, ax = plt.subplots(figsize = (10,9))
sns.set_color_codes('pastel')
sns.countplot(y = 'PREMISE_TYPE', data = data,
            label = 'Premise Type', color = 'g', edgecolor = 'w')
sns.set_color_codes('muted')
ax.legend(ncol = 2, loc = 'lower right')
sns.despine(left = True, bottom = True)
plt.show()

# %%
#sns.countplot(y='CRIME_TYPE', data=data);
sns.set_context('paper')

f, ax = plt.subplots(figsize = (15,6))
sns.set_color_codes('pastel')
sns.countplot(y = 'CRIME_TYPE', data = data,
            label = 'Crime Type', color = 'g', edgecolor = 'w')
sns.set_color_codes('muted')
ax.legend(ncol = 2, loc = 'upper right')
sns.despine(left = True, bottom = True)
plt.show()

# %%
#sns.countplot(y='CRIME_TYPE', data=data);
sns.set_context('paper')

f, ax = plt.subplots(figsize = (10,9))
sns.set_color_codes('pastel')
sns.countplot(y = 'LMPD_DIVISION', data = data,
            label = 'LMPD_DIVISION', color = 'g', edgecolor = 'w')
sns.set_color_codes('muted')
ax.legend(ncol = 2, loc = 'lower right')
sns.despine(left = True, bottom = True)
plt.show()

# %%
data = data.groupby(['ZIP_CODE']).size().sort_values(ascending=False)
data
# Out:
# ZIP_CODE
# DRIVEWAY    1
# 40212.0     1
# 40214.0     1
# 40215.0     1
# 40216.0     1
#            ..
# 40210       1
# 40211       1
# 40212       1
# 40213       1
# 4291.0      1
# Length: 115, dtype: int64

# %%
#sns.countplot(y='CRIME_TYPE', data=data);
sns.set_context('paper')

f, ax = plt.subplots(figsize = (15,6))
sns.set_color_codes('pastel')
sns.countplot(y='ZIP_CODE', data.groupby(['ZIP_CODE']).size().sort_values(ascending=False),
            label = 'Zip Code', color = 'g', edgecolor = 'w')
sns.set_color_codes('muted')
ax.legend(ncol = 2, loc = 'upper right')
sns.despine(left = True, bottom = True)
plt.show()
# Out:
#   File "<ipython-input-55-9f1b608023d4>", line 6
#     sns.countplot(y='ZIP_CODE', data.groupby(['ZIP_CODE']).size().sort_values(ascending=False),
#                                 ^
# SyntaxError: positional argument follows keyword argument
